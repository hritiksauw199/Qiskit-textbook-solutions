# %%
from qiskit import QuantumCircuit
import qiskit.quantum_info as qi

# %% [markdown]
# # Exercise 1.1

# %% [markdown]
# ![q1.png](attachment:q1.png)

# %% [markdown]
# ![photo_2022-02-24_20-46-24.jpg](attachment:photo_2022-02-24_20-46-24.jpg)

# %%
qc_AB = QuantumCircuit(1)
qc_AB.h(0)
qc_AB.s(0)
qc_AB.z(0)
qc_AB.draw()
# Out:
#      ┌───┐┌───┐┌───┐
# q_0: ┤ H ├┤ S ├┤ Z ├
#      └───┘└───┘└───┘

# %%
psi_AB = qi.Statevector.from_instruction(qc_AB)
psi_AB.draw('latex', prefix='|\\psi_{AB}\\rangle = ')
# Out:
# $$
# |\psi_{AB}\rangle =
# \begin{bmatrix}
# \tfrac{1}{\sqrt{2}} & -\tfrac{1}{\sqrt{2}}i  \\
#  \end{bmatrix}
# $$

# %%
rho_AB = qi.DensityMatrix.from_instruction(qc_AB)
rho_AB.draw('latex', prefix='\\rho_{AB} = ')
# Out:
# $$
# \rho_{AB} =
# \begin{bmatrix}
# \tfrac{1}{2} & \tfrac{1}{2}i  \\
#  -\tfrac{1}{2}i & \tfrac{1}{2}  \\
#  \end{bmatrix}
# $$

# %%
from qiskit.visualization import plot_state_city
plot_state_city(rho_AB.data, title='Density Matrix')

# %% [markdown]
# ![photo_2022-02-24_20-46-31.jpg](attachment:photo_2022-02-24_20-46-31.jpg)

# %%
qc_AB = QuantumCircuit(2)
qc_AB.h(0)
qc_AB.h(1)
qc_AB.draw()
# Out:
#      ┌───┐
# q_0: ┤ H ├
#      ├───┤
# q_1: ┤ H ├
#      └───┘

# %%
psi_AB = qi.Statevector.from_instruction(qc_AB)
psi_AB.draw('latex', prefix='|\\psi_{AB}\\rangle = ')
# Out:
# $$
# |\psi_{AB}\rangle =
# \begin{bmatrix}
# \tfrac{1}{2} & \tfrac{1}{2} & \tfrac{1}{2} & \tfrac{1}{2}  \\
#  \end{bmatrix}
# $$

# %%
rho_AB = qi.DensityMatrix.from_instruction(qc_AB)
rho_AB.draw('latex', prefix='\\rho_{AB} = ')
# Out:
# $$
# \rho_{AB} =
# \begin{bmatrix}
# \tfrac{1}{4} & \tfrac{1}{4} & \tfrac{1}{4} & \tfrac{1}{4}  \\
#  \tfrac{1}{4} & \tfrac{1}{4} & \tfrac{1}{4} & \tfrac{1}{4}  \\
#  \tfrac{1}{4} & \tfrac{1}{4} & \tfrac{1}{4} & \tfrac{1}{4}  \\
#  \tfrac{1}{4} & \tfrac{1}{4} & \tfrac{1}{4} & \tfrac{1}{4}  \\
#  \end{bmatrix}
# $$

# %%
from qiskit.visualization import plot_state_city
plot_state_city(rho_AB.data, title='Density Matrix')

# %% [markdown]
# # Exercise 2.2

# %% [markdown]
# ![1.png](attachment:1.png)

# %% [markdown]
# ![photo_2022-02-27_11-28-04.jpg](attachment:photo_2022-02-27_11-28-04.jpg)

# %% [markdown]
# # Exercise 4.1

# %% [markdown]
# ![5.png](attachment:5.png)

# %% [markdown]
# **1)** For mathematical workout please see the pdf attached in the repo, titled 'Reduced_Density_Unsolved'

# %%
qc_AB = QuantumCircuit(2)
qc_AB.h(0)
qc_AB.h(1)
qc_AB.draw()
# Out:
#      ┌───┐
# q_0: ┤ H ├
#      ├───┤
# q_1: ┤ H ├
#      └───┘

# %%
psi_AB = qi.Statevector.from_instruction(qc_AB)
psi_AB.draw('latex', prefix='|\\psi_{AB}\\rangle = ')
# Out:
# $$
# |\psi_{AB}\rangle =
# \begin{bmatrix}
# \tfrac{1}{2} & \tfrac{1}{2} & \tfrac{1}{2} & \tfrac{1}{2}  \\
#  \end{bmatrix}
# $$

# %%
rho_AB = qi.DensityMatrix.from_instruction(qc_AB)
rho_AB.draw('latex', prefix='\\rho_{AB} = ')
# Out:
# $$
# \rho_{AB} =
# \begin{bmatrix}
# \tfrac{1}{4} & \tfrac{1}{4} & \tfrac{1}{4} & \tfrac{1}{4}  \\
#  \tfrac{1}{4} & \tfrac{1}{4} & \tfrac{1}{4} & \tfrac{1}{4}  \\
#  \tfrac{1}{4} & \tfrac{1}{4} & \tfrac{1}{4} & \tfrac{1}{4}  \\
#  \tfrac{1}{4} & \tfrac{1}{4} & \tfrac{1}{4} & \tfrac{1}{4}  \\
#  \end{bmatrix}
# $$

# %%
rho_B = qi.partial_trace(rho_AB,[0])
rho_A = qi.partial_trace(rho_AB,[1])

display(rho_B.draw('latex', prefix=" \\rho_{B} = "),
        rho_A.draw('latex', prefix=" \\rho_{A} = "))
# Out:
# $$
#  \rho_{B} =
# \begin{bmatrix}
# \tfrac{1}{2} & \tfrac{1}{2}  \\
#  \tfrac{1}{2} & \tfrac{1}{2}  \\
#  \end{bmatrix}
# $$
# $$
#  \rho_{A} =
# \begin{bmatrix}
# \tfrac{1}{2} & \tfrac{1}{2}  \\
#  \tfrac{1}{2} & \tfrac{1}{2}  \\
#  \end{bmatrix}
# $$

# %% [markdown]
# **2)** Please see the pdf attached in the repo, titled 'Reduced_Density_Unsolved'
